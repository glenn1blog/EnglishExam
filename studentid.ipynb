# %% [markdown]
# <a href="https://colab.research.google.com/github/glenn1blog/EnglishExam/blob/main/studentid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests 
from bs4 import BeautifulSoup

if __name__ == '__main__':
    cookie = '''ITOUCHCOOKIE=5ccba3d8d2c5767238be79a1d26e8149e7c49df4d7192b070fa699c700d8e250668c2d2f; _ga=GA1.3.1269263312.1620634041; _gid=GA1.3.1738652938.1620634041; JSESSIONID=BF5D5CE275CD5732DDC0F4744C4C640D'''
      
    header = {
    'User-Agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 13_2_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.3 Mobile/15E148 Safari/604.1',
    'Connection': 'keep-alive',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Cookie': cookie}

    stuid = input("輸入學號")

    if len(stuid) != 8:
      
      for i in range(6, 10):
        for j in range(100, 300):
          url = 'https://itouch.cycu.edu.tw/active_project/cycu2100h_18/case_09/validate_id.jsp?id=10'+ str(i) +'15'+ str(j) #str(i).rjust(2,'0')
          html_doc = requests.get(url,headers=header).text
          soup = BeautifulSoup(html_doc,'lxml')
          if soup.find('input', {'name': 'STMD_ID'}).get('value') == "null":
            continue
          print(soup.find('input', {'name': 'STMD_ID'}).get('value') + " " + soup.find('input', {'name': 'STMD_NAME'}).get('value'))
          all = j*i
        print("\n")
      print("總人數:" + str(all))
    else:
      url = 'https://itouch.cycu.edu.tw/active_project/cycu2100h_18/case_09/validate_id.jsp?id=' + stuid
      html_doc = requests.get(url,headers=header).text
      soup = BeautifulSoup(html_doc,'lxml')
      if soup.find('input', {'name': 'STMD_ID'}).get('value') == "null":
        print("這學號沒有人")
      else:
        print(soup.find('input', {'name': 'STMD_ID'}).get('value') + " " + soup.find('input', {'name': 'STMD_NAME'}).get('value'))
# Out:
# 輸入學號1
# 10615101 陳虹彣
# 10615102 吳軒萱
# 10615103 彭芷桐
# 10615104 廖廷偉
# 10615105 黃湘芸
# 10615106 李亦翔
# 10615107 徐璟宏
# 10615108 蔡芷芸
# 10615109 張逸權
# 10615110 高筱涵
# 10615111 顏嘉德
# 10615112 李姿月
# 10615113 林性美
# 10615114 蔡雨芯
# 10615115 李欣如
# 10615116 管柏偉
# 10615117 周柏辰
# 10615118 楊佳佳
# 10615119 黃思翰
# 10615120 康毓蘋
# 10615121 林子晴
# 10615122 游榮彬
# 10615123 蘇晨豪
# 10615124 林朕宇
# 10615125 許雅欣
# 10615126 黃柏瑜
# 10615127 陳彥仁
# 10615128 賴芊彣
# 10615129 尹中鉉
# 10615130 李奇霖
# 10615131 陳忠聖
# 10615132 黃瀞儀
# 10615133 許維辰
# 10615134 李珮慈
# 10615135 黃詩方
# 10615136 呂姝葵
# 10615137 陳建達
# 10615138 劉育鑫
# 10615139 陳　欣
# 10615140 蔡沛涔
# 10615141 田紫緹
# 10615142 黃薏瑄
# 10615143 施品妤
# 10615144 陳識安
# 10615145 朱育葳
# 10615146 江沛芯
# 10615147 彭偉華
# 10615148 秦　崎
# 10615149 廖婉瑜
# 10615150 林琮憲
# 10615151 邱鐘鈺
# 10615152 賴柏學
# 10615155 田瀞妤
# 10615156 蕭凱隆
# 10615170 郭睿
# 10615172 陳軒禾
# 10615201 許庭禎
# 10615202 陳詩淇
# 10615203 吳家瀅
# 10615204 葉志騏
# 10615205 高佳賢
# 10615206 黃婉萍
# 10615207 莊承佑
# 10615208 顏嫚妤
# 10615209 翁瑜鄉
# 10615210 廖韋綸
# ...
